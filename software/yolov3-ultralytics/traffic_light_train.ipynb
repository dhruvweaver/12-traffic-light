# %% [markdown]
# # Traffic Light Detection Training
#
# This notebook gathers data from Roboflow, and then trains the YOLOv3 object detection model.

# %% [markdown]
# ### Import traffic light training images:

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="WhwGnkSP0eEcTs3SCw6P")
project = rf.workspace("traffic-light-detection-qsrxn").project("traffic-light-oq7uj")
dataset = project.version(25).download("yolov5")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
#
# Version export complete for yolov5pytorch format
# ...
# Extracting Dataset Version Zip to traffic-light-25 in yolov5pytorch:: 100%|████████████████████████████████████████████| 5064/5064 [00:00<00:00, 12888.67it/s]

# %% [markdown]
# ### Train model with imported images:
# Currently set up to train with 2000 epochs and a batch size of 32

# %%
# !python train.py --data ./traffic-light-25/data.yaml --epochs 2000 --weights '' --cfg yolov5n.yaml  --batch-size 32
# Out:
# train: weights=, cfg=yolov5n.yaml, data=./traffic-light-25/data.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=2000, batch_size=32, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: skipping check (not a git repository), for updates see https://github.com/ultralytics/yolov5
# YOLOv3 🚀 2023-10-26 Python-3.11.6 torch-2.1.0+cu121 CUDA:0 (NVIDIA GeForce RTX 2070, 7972MiB)
#
# ...
