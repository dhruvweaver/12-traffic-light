# %%
! python3 detect.py --source 0
# Out:
# detect: weights=yolov5s.pt, source=0, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_csv=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# WARNING ⚠️ invalid check_version(5.9.5, ) requested, please check values.
# YOLOv5 🚀 v7.0-224-g6262c7f Python-3.10.10 torch-2.0.1 CPU
#
# Fusing layers...
# YOLOv5s summary: 213 layers, 7225885 parameters, 0 gradients
# 1/1: 0...  Success (inf frames 1920x1080 at 30.00 FPS)
#
# 0: 384x640 (no detections), 71.2ms
# 0: 384x640 (no detections), 69.0ms
# 0: 384x640 1 keyboard, 54.4ms
# 0: 384x640 1 keyboard, 54.4ms
# 0: 384x640 (no detections), 62.1ms
# 0: 384x640 (no detections), 54.0ms
# 0: 384x640 (no detections), 55.4ms
# ...

# %%
import roboflow

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="RBQPDeOlmiY1GViFvGGF")
project = rf.workspace("yolov5-traffic-light-dataset").project("yolov5_cardataset")
dataset = project.version(7).download("yolov5")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to Yolov5_CarDataset-7 in yolov5pytorch:: 100%|█|

# %%
! python3 train.py --img 416 --epochs 3 --data "data/custom_dataset.yaml" --weights yolov5s.pt
# Out:
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/tensorboard/compat/__init__.py", line 42, in tf
#     from tensorboard.compat import notf  # noqa: F401
# ImportError: cannot import name 'notf' from 'tensorboard.compat' (/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/tensorboard/compat/__init__.py)
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/sohnchanwoo/yolov5/train.py", line 61, in <module>
#     from utils.loggers import Loggers
#   File "/Users/sohnchanwoo/yolov5/utils/loggers/__init__.py", line 23, in <module>
#     from torch.utils.tensorboard import SummaryWriter
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/torch/utils/tensorboard/__init__.py", line 12, in <module>
#     from .writer import FileWriter, SummaryWriter  # noqa: F401
# ...

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="RBQPDeOlmiY1GViFvGGF")
project = rf.workspace("version-ou-je-vais-merge").project("traffic-lights-qh0vp")
dataset = project.version(1).download("yolov5")
# Out:
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to traffic-lights-1 in yolov5pytorch:: 100%|█| 41

# %%
! python3 train.py --img 640 --epochs 3 --data "data/traffic_lights_1.yaml" --weights yolov5s.pt
# Out:
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/tensorboard/compat/__init__.py", line 42, in tf
#     from tensorboard.compat import notf  # noqa: F401
# ImportError: cannot import name 'notf' from 'tensorboard.compat' (/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/tensorboard/compat/__init__.py)
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/sohnchanwoo/yolov5/train.py", line 61, in <module>
#     from utils.loggers import Loggers
#   File "/Users/sohnchanwoo/yolov5/utils/loggers/__init__.py", line 23, in <module>
#     from torch.utils.tensorboard import SummaryWriter
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/torch/utils/tensorboard/__init__.py", line 12, in <module>
#     from .writer import FileWriter, SummaryWriter  # noqa: F401
# ...

# %%
# !python3 detect.py --weights "/Users/sohnchanwoo/yolov5/runs/train/epoch70/weights/best.pt" --source 0
# Out:
# detect: weights=['/Users/sohnchanwoo/yolov5/runs/train/epoch70/weights/best.pt'], source=0, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_csv=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# WARNING ⚠️ invalid check_version(5.9.5, ) requested, please check values.
# YOLOv5 🚀 v7.0-224-g6262c7f Python-3.10.10 torch-2.0.1 CPU
#
# Fusing layers...
# Model summary: 157 layers, 7018216 parameters, 0 gradients, 15.8 GFLOPs
# 1/1: 0...  Success (inf frames 1920x1080 at 30.00 FPS)
#
# 0: 384x640 (no detections), 83.7ms
# 0: 384x640 (no detections), 52.5ms
# 0: 384x640 (no detections), 50.5ms
# 0: 384x640 (no detections), 50.4ms
# 0: 384x640 (no detections), 49.2ms
# ...
